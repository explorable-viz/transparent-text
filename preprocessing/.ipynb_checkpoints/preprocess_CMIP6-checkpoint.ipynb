# %%
import pandas as pd
from os import listdir

# %%
filenames = listdir('CMIP6_tas_landsea')

# %%
res = map(lambda x: x.split('_'), filenames)

# %%
scenarios = ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585']

# %%
filename = [file for file in listdir('CMIP6_tas_landsea') if ('EC-Earth3' in file.split('_')) and ('ssp126' in file) ]

# %%
filename
# Out:
# ['CMIP6_EC-Earth3_ssp126_r1i1p1f1.csv']

# %%
def get_model_name(filename):
    return filename.split('_')[1]

# %%
print(get_model_name('CMIP6_HadGEM3-GC31-LL_ssp245_r1i1p1f3.csv'))
# Out:
# HadGEM3-GC31-LL

# %%
def scenario_df(scenario):
    frames = []
    filenames = [file for file in listdir('CMIP6_tas_landsea') if scenario in file]
    for file in filenames:
        model_name = get_model_name(file)
        df = pd.read_csv('CMIP6_tas_landsea/' + file, header=15, usecols=['date', 'world'])
        df['scenario'] = scenario
        df['model'] = model_name
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %%
ssp126 = scenario_df('ssp126')
ssp245 = scenario_df('ssp245')
ssp370 = scenario_df('ssp370')
ssp585 = scenario_df('ssp585')

# %%
def dateify_proj(frames):
    for frame in frames:
        frame['date'] = pd.to_datetime(frame['date'], format='%Y-%m')
all_scenarios = [ssp126, ssp245, ssp370, ssp585]
dateify_proj(all_scenarios)

# %%
bins = [2021, 2041, 2061, 2081, 2101]
labels = ['2021-2040', '2041-2060', '2061-2080', '2081-2100']
models = ['UKESM1-0-LL', 'CMCC-CM2-SR5', 'MPI-ESM1-2-HR', 'NorESM2-MM', 'INM-CM4-8',
 'ACCESS-ESM1-5', 'CNRM-CM6-1', 'MRI-ESM2-0', 'NESM3', 'CESM2', 'ACCESS-CM2',
 'MPI-ESM1-2-LR', 'EC-Earth3-Veg', 'IITM-ESM', 'MIROC6', 'BCC-CSM2-MR',
 'INM-CM5-0', 'AWI-CM-1-1-MR', 'FGOALS-g3', 'EC-Earth3', 'NorESM2-LM',
 'GFDL-ESM4', 'KACE-1-0-G', 'CNRM-ESM2-1', 'MIROC-ES2L', 'CAMS-CSM1-0',
 'CanESM5', 'IPSL-CM6A-LR', 'CNRM-CM6-1-HR', 'HadGEM3-GC31-LL', 'KIOST-ESM',
 'CESM2-WACCM']

# %%
def groups_20_year(frame):
    frame['period'] = pd.cut(frame['date'].dt.year, bins=bins, labels=labels, right=False)
    return frame.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()

# %%
ssp126Avgs = groups_20_year(ssp126)
ssp245Avgs = groups_20_year(ssp245)
ssp370Avgs = groups_20_year(ssp370)
ssp585Avgs = groups_20_year(ssp585)
# Out:
# /tmp/ipykernel_3308590/2331576031.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return frame.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()
# /tmp/ipykernel_3308590/2331576031.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return frame.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()
# /tmp/ipykernel_3308590/2331576031.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return frame.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()
# /tmp/ipykernel_3308590/2331576031.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return frame.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()

# %%
[ssp126Avgs, ssp245Avgs, ssp370Avgs, ssp585Avgs]
# Out:
# [    scenario          model     period      world
#  0     ssp126     ACCESS-CM2  2021-2040  15.393788
#  1     ssp126     ACCESS-CM2  2041-2060  15.993688
#  2     ssp126     ACCESS-CM2  2061-2080  16.195675
#  3     ssp126     ACCESS-CM2  2081-2100  16.268829
#  4     ssp126  ACCESS-ESM1-5  2021-2040  16.016575
#  ..       ...            ...        ...        ...
#  123   ssp126     NorESM2-MM  2081-2100  15.222408
#  124   ssp126    UKESM1-0-LL  2021-2040  15.196275
#  125   ssp126    UKESM1-0-LL  2041-2060  15.761942
#  126   ssp126    UKESM1-0-LL  2061-2080  15.971892
#  127   ssp126    UKESM1-0-LL  2081-2100  16.059575
#
#  [128 rows x 4 columns],
#      scenario          model     period      world
#  0     ssp245     ACCESS-CM2  2021-2040  15.371642
#  1     ssp245     ACCESS-CM2  2041-2060  16.180617
#  2     ssp245     ACCESS-CM2  2061-2080  16.759508
#  3     ssp245     ACCESS-CM2  2081-2100  17.181108
#  4     ssp245  ACCESS-ESM1-5  2021-2040  16.063804
#  ..       ...            ...        ...        ...
#  131   ssp245     NorESM2-MM  2081-2100  16.003412
#  132   ssp245    UKESM1-0-LL  2021-2040  15.234554
#  133   ssp245    UKESM1-0-LL  2041-2060  16.078163
#  134   ssp245    UKESM1-0-LL  2061-2080  16.764487
#  135   ssp245    UKESM1-0-LL  2081-2100  17.394467
#
#  [136 rows x 4 columns],
#      scenario          model     period      world
#  0     ssp370     ACCESS-CM2  2021-2040  15.398288
#  1     ssp370     ACCESS-CM2  2041-2060  16.202225
#  2     ssp370     ACCESS-CM2  2061-2080  17.165658
#  3     ssp370     ACCESS-CM2  2081-2100  18.266475
#  4     ssp370  ACCESS-ESM1-5  2021-2040  15.961896
#  ..       ...            ...        ...        ...
#  115   ssp370     NorESM2-MM  2081-2100  16.897179
#  116   ssp370    UKESM1-0-LL  2021-2040  15.345067
#  117   ssp370    UKESM1-0-LL  2041-2060  16.434733
#  118   ssp370    UKESM1-0-LL  2061-2080  17.457567
#  119   ssp370    UKESM1-0-LL  2081-2100  18.860783
#
#  [120 rows x 4 columns],
#      scenario          model     period      world
#  0     ssp585     ACCESS-CM2  2021-2040  15.447654
#  1     ssp585     ACCESS-CM2  2041-2060  16.459837
#  2     ssp585     ACCESS-CM2  2061-2080  17.755267
#  3     ssp585     ACCESS-CM2  2081-2100  19.228154
#  4     ssp585  ACCESS-ESM1-5  2021-2040  16.169304
#  ..       ...            ...        ...        ...
#  131   ssp585        TaiESM1  2081-2100  19.543917
#  132   ssp585    UKESM1-0-LL  2021-2040  15.336979
#  133   ssp585    UKESM1-0-LL  2041-2060  16.665758
#  134   ssp585    UKESM1-0-LL  2061-2080  18.251633
#  135   ssp585    UKESM1-0-LL  2081-2100  19.904204
#
#  [136 rows x 4 columns]]

# %%
ssp126
# Out:
#             date   world scenario        model     period
# 0     2015-01-01  12.338   ssp126  UKESM1-0-LL        NaN
# 1     2015-02-01  12.530   ssp126  UKESM1-0-LL        NaN
# 2     2015-03-01  13.251   ssp126  UKESM1-0-LL        NaN
# 3     2015-04-01  14.239   ssp126  UKESM1-0-LL        NaN
# 4     2015-05-01  15.185   ssp126  UKESM1-0-LL        NaN
# ...          ...     ...      ...          ...        ...
# 32995 2100-08-01  18.024   ssp126  CESM2-WACCM  2081-2100
# 32996 2100-09-01  17.271   ssp126  CESM2-WACCM  2081-2100
# 32997 2100-10-01  16.414   ssp126  CESM2-WACCM  2081-2100
# 32998 2100-11-01  15.591   ssp126  CESM2-WACCM  2081-2100
# 32999 2100-12-01  14.885   ssp126  CESM2-WACCM  2081-2100
#
# [33000 rows x 5 columns]

# %%
historical = scenario_df('historical')

# %%
historical
# Out:
#           date   world    scenario             model
# 0      1850-01  10.963  historical       UKESM1-0-LL
# 1      1850-02  11.175  historical       UKESM1-0-LL
# 2      1850-03  12.154  historical       UKESM1-0-LL
# 3      1850-04  13.219  historical       UKESM1-0-LL
# 4      1850-05  14.191  historical       UKESM1-0-LL
# ...        ...     ...         ...               ...
# 60475  2014-08  16.691  historical  EC-Earth3-Veg-LR
# 60476  2014-09  15.942  historical  EC-Earth3-Veg-LR
# 60477  2014-10  14.874  historical  EC-Earth3-Veg-LR
# 60478  2014-11  13.510  historical  EC-Earth3-Veg-LR
# 60479  2014-12  12.724  historical  EC-Earth3-Veg-LR
#
# [60480 rows x 4 columns]

# %%
historical_bins = [1850, 1901]
historical_label = ['1850-1901']
historical['date'] = historical['date'] = pd.to_datetime(historical['date'], format='%Y-%m')
historical['period'] = pd.cut(historical['date'].dt.year, bins=historical_bins, labels=historical_label, right=False)
historicalAvgs = historical.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()
# Out:
# /tmp/ipykernel_3308590/4210085770.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   historicalAvgs = historical.groupby(['scenario', 'model', 'period'])['world'].mean().reset_index()

# %%
historicalAvgs
# Out:
#       scenario             model     period      world
# 0   historical        ACCESS-CM2  1850-1901  13.760598
# 1   historical     ACCESS-ESM1-5  1850-1901  14.516224
# 2   historical     AWI-CM-1-1-MR  1850-1901  13.706546
# 3   historical       BCC-CSM2-MR  1850-1901  14.740028
# 4   historical       CAMS-CSM1-0  1850-1901  13.837046
# 5   historical             CESM2  1850-1901  13.970564
# 6   historical       CESM2-WACCM  1850-1901  13.793817
# 7   historical      CMCC-CM2-SR5  1850-1901  14.049627
# 8   historical        CNRM-CM6-1  1850-1901  12.855534
# 9   historical     CNRM-CM6-1-HR  1850-1901  12.370842
# 10  historical       CNRM-ESM2-1  1850-1901  13.658054
# 11  historical           CanESM5  1850-1901  13.562603
# 12  historical         EC-Earth3  1850-1901  13.962964
# 13  historical     EC-Earth3-Veg  1850-1901  13.578273
# 14  historical  EC-Earth3-Veg-LR  1850-1901  13.532118
# 15  historical         FGOALS-g3  1850-1901  12.834928
# 16  historical          GFDL-CM4  1850-1901  12.757936
# 17  historical         GFDL-ESM4  1850-1901  13.408075
# 18  historical   HadGEM3-GC31-LL  1850-1901  13.595260
# 19  historical          IITM-ESM  1850-1901  14.096688
# 20  historical         INM-CM4-8  1850-1901  13.330208
# 21  historical         INM-CM5-0  1850-1901  13.171436
# 22  historical      IPSL-CM6A-LR  1850-1901  12.817900
# 23  historical        KACE-1-0-G  1850-1901  13.546874
# 24  historical         KIOST-ESM  1850-1901  12.478552
# 25  historical        MIROC-ES2L  1850-1901  15.024985
# 26  historical            MIROC6  1850-1901  15.255964
# 27  historical     MPI-ESM1-2-HR  1850-1901  13.924686
# 28  historical     MPI-ESM1-2-LR  1850-1901  13.520881
# 29  historical        MRI-ESM2-0  1850-1901  13.731557
# 30  historical             NESM3  1850-1901  13.632525
# 31  historical        NorESM2-LM  1850-1901  14.495253
# 32  historical        NorESM2-MM  1850-1901  13.883054
# 33  historical           TaiESM1  1850-1901  13.927887
# 34  historical       UKESM1-0-LL  1850-1901  13.385397

# %%
ssp126Avgs
# Out:
#     scenario          model     period      world
# 0     ssp126     ACCESS-CM2  2021-2040  15.393788
# 1     ssp126     ACCESS-CM2  2041-2060  15.993688
# 2     ssp126     ACCESS-CM2  2061-2080  16.195675
# 3     ssp126     ACCESS-CM2  2081-2100  16.268829
# 4     ssp126  ACCESS-ESM1-5  2021-2040  16.016575
# ..       ...            ...        ...        ...
# 123   ssp126     NorESM2-MM  2081-2100  15.222408
# 124   ssp126    UKESM1-0-LL  2021-2040  15.196275
# 125   ssp126    UKESM1-0-LL  2041-2060  15.761942
# 126   ssp126    UKESM1-0-LL  2061-2080  15.971892
# 127   ssp126    UKESM1-0-LL  2081-2100  16.059575
#
# [128 rows x 4 columns]

# %%
ssp126merged = pd.merge(ssp126Avgs, historicalAvgs[['model', 'world']], on='model', suffixes=('', '_historical'))
ssp245merged = pd.merge(ssp245Avgs, historicalAvgs[['model', 'world']], on='model', suffixes=('', '_historical'))
ssp370merged = pd.merge(ssp370Avgs, historicalAvgs[['model', 'world']], on='model', suffixes=('', '_historical'))
ssp585merged = pd.merge(ssp585Avgs, historicalAvgs[['model', 'world']], on='model', suffixes=('', '_historical'))

# %%
def collect_changes(frame):
    frame['changed'] = frame['world'] - frame['world_historical']
    return frame.drop(columns=['world_historical'])
mergeds = [ssp126merged, ssp245merged, ssp370merged, ssp585merged]

changeds = map(collect_changes, mergeds)

# %%
for frame in changeds:
    print(frame)
# Out:
#     scenario          model     period      world   changed
# 0     ssp126     ACCESS-CM2  2021-2040  15.393788  1.633189
# 1     ssp126     ACCESS-CM2  2041-2060  15.993688  2.233089
# 2     ssp126     ACCESS-CM2  2061-2080  16.195675  2.435077
# 3     ssp126     ACCESS-CM2  2081-2100  16.268829  2.508231
# 4     ssp126  ACCESS-ESM1-5  2021-2040  16.016575  1.500351
# ..       ...            ...        ...        ...       ...
# 123   ssp126     NorESM2-MM  2081-2100  15.222408  1.339354
# 124   ssp126    UKESM1-0-LL  2021-2040  15.196275  1.810878
# 125   ssp126    UKESM1-0-LL  2041-2060  15.761942  2.376545
# 126   ssp126    UKESM1-0-LL  2061-2080  15.971892  2.586495
# 127   ssp126    UKESM1-0-LL  2081-2100  16.059575  2.674178
#
# [128 rows x 5 columns]
#     scenario          model     period      world   changed
# 0     ssp245     ACCESS-CM2  2021-2040  15.371642  1.611044
# 1     ssp245     ACCESS-CM2  2041-2060  16.180617  2.420019
# 2     ssp245     ACCESS-CM2  2061-2080  16.759508  2.998910
# 3     ssp245     ACCESS-CM2  2081-2100  17.181108  3.420510
# 4     ssp245  ACCESS-ESM1-5  2021-2040  16.063804  1.547580
# ..       ...            ...        ...        ...       ...
# 131   ssp245     NorESM2-MM  2081-2100  16.003412  2.120359
# 132   ssp245    UKESM1-0-LL  2021-2040  15.234554  1.849157
# 133   ssp245    UKESM1-0-LL  2041-2060  16.078163  2.692765
# 134   ssp245    UKESM1-0-LL  2061-2080  16.764487  3.379090
# 135   ssp245    UKESM1-0-LL  2081-2100  17.394467  4.009070
#
# [136 rows x 5 columns]
#     scenario          model     period      world   changed
# 0     ssp370     ACCESS-CM2  2021-2040  15.398288  1.637689
# 1     ssp370     ACCESS-CM2  2041-2060  16.202225  2.441627
# 2     ssp370     ACCESS-CM2  2061-2080  17.165658  3.405060
# 3     ssp370     ACCESS-CM2  2081-2100  18.266475  4.505877
# 4     ssp370  ACCESS-ESM1-5  2021-2040  15.961896  1.445672
# ..       ...            ...        ...        ...       ...
# 115   ssp370     NorESM2-MM  2081-2100  16.897179  3.014125
# 116   ssp370    UKESM1-0-LL  2021-2040  15.345067  1.959670
# 117   ssp370    UKESM1-0-LL  2041-2060  16.434733  3.049336
# 118   ssp370    UKESM1-0-LL  2061-2080  17.457567  4.072170
# 119   ssp370    UKESM1-0-LL  2081-2100  18.860783  5.475386
#
# [120 rows x 5 columns]
#     scenario          model     period      world   changed
# 0     ssp585     ACCESS-CM2  2021-2040  15.447654  1.687056
# 1     ssp585     ACCESS-CM2  2041-2060  16.459837  2.699239
# 2     ssp585     ACCESS-CM2  2061-2080  17.755267  3.994669
# 3     ssp585     ACCESS-CM2  2081-2100  19.228154  5.467556
# 4     ssp585  ACCESS-ESM1-5  2021-2040  16.169304  1.653080
# ..       ...            ...        ...        ...       ...
# 131   ssp585        TaiESM1  2081-2100  19.543917  5.616029
# 132   ssp585    UKESM1-0-LL  2021-2040  15.336979  1.951582
# 133   ssp585    UKESM1-0-LL  2041-2060  16.665758  3.280361
# 134   ssp585    UKESM1-0-LL  2061-2080  18.251633  4.866236
# 135   ssp585    UKESM1-0-LL  2081-2100  19.904204  6.518807
#
# [136 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
periods = ['2021-2040', '2041-2060', '2061-2080', '2081-2100']
scenario = 'ssp126'
frame = ssp126merged
for period in periods:
    plt.figure(figsize=(8, 6))
    period_data = frame[frame['period'] == period]
    n, bins, patches = plt.hist(period_data['changed'], bins=10, edgecolor='black', alpha=0.7, density=True)
    plt.title('Distribution of predicted changes for scenario ' + scenario + ' during ' + period, fontsize=14)
    bin_labels = [f"{bins[i]:.1f}" for i in range(len(bins))]
    plt.xticks(bins, bin_labels, rotation=45)
    plt.xlabel('Amount of change', fontsize=10)
    plt.ylabel('Density', fontsize=10)
    plt.show()

# %%
import numpy as np

ssp126merged['changed']
# Out:
# 0      1.633189
# 1      2.233089
# 2      2.435077
# 3      2.508231
# 4      1.500351
#          ...
# 123    1.339354
# 124    1.810878
# 125    2.376545
# 126    2.586495
# 127    2.674178
# Name: changed, Length: 128, dtype: float64

# %%
for period in periods:
    print(np.percentile(ssp245merged[ssp245merged['period'] == period]['changed'], [5, 50, 95], axis=None, interpolation='linear'))
# Out:
# [1.07279097 1.53170323 2.07386493]
# [1.52945985 2.074548   2.78599157]
# [1.80413027 2.56064212 3.42785928]
# [2.11159422 2.9483482  3.89537739]

# %%
import math
def mypercentile(arr, p):
    sorted = np.sort(arr)
    rank = (p/100) * (len(arr)-1)
    print("Rank: " + str(rank))
    if rank == math.floor(rank):
        return arr.iloc[rank]
    else:
        print("Interpolating: ")
        x1 = math.floor(rank)
        x2 = math.ceil(rank)
        return arr.iloc[x1] + (rank - math.floor(rank))*(arr.iloc[x2] - arr.iloc[x1])
for period in periods:
    print(mypercentile(ssp245merged[ssp245merged['period'] == period]['changed'], 50))
# Out:
# Rank: 16.5
# Interpolating:
# 1.3802151143790846
# Rank: 16.5
# Interpolating:
# 1.8112151143790847
# Rank: 16.5
# Interpolating:
# 2.2371713643790843
# Rank: 16.5
# Interpolating:
# 2.580196364379084
